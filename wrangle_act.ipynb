# %%
import pandas as pd
import requests
import numpy as np
import tweepy
import json
import matplotlib.pyplot as plt
import os
import datetime
import time
import seaborn as sns
from wordcloud import WordCloud
from matplotlib.pyplot import figure
from pylab import rcParams
import cufflinks as cf
cf.go_offline()


# %matplotlib inline

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Gathering

# %%
# gathering the main file manually

archive_df = pd.read_csv('twitter-archive-enhanced.csv')
archive_df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
# downloading the image data file with code 

url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
with open ('image-predictions.tsv', mode = 'wb') as file:
    file.write(response.content)

images_df = pd.read_csv('image-predictions.tsv', sep='\t')
images_df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#twitter api

consumer_key = 'Hidden'
consumer_secret = 'Hidden'
access_token = 'Hidden'
access_secret = 'Hidden'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit = True, 
                 wait_on_rate_limit_notify = True)

# %%
# creating json data by using the api

found = []
not_found = []

if not os.path.isfile('tweet_json.txt'):
    with open('tweet_json.txt', 'w') as my_list:
        for ID in archive_df.tweet_id:
            try:
                tweet = api.get_status(ID, tweet_mode='extended')
                json.dump(tweet._json, my_list)
                found.append(ID)
                my_list.write('\n')
            except Exception as e:
                not_found.append(ID)
                print(ID)

# %%
api_df = pd.read_json('tweet_json.txt', lines = True,encoding='utf-8')
api_df.keys()
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'extended_entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive',
#        'possibly_sensitive_appealable', 'lang', 'retweeted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status_permalink',
#        'quoted_status'],
#       dtype='object')

# %%
api_df
# Out:
#                     created_at                  id              id_str  \
# 0    2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1    2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2    2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3    2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4    2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
# ...                        ...                 ...                 ...
# 2326 2015-11-16 00:24:50+00:00  666049248165822465  666049248165822464
# 2327 2015-11-16 00:04:52+00:00  666044226329800704  666044226329800704
# 2328 2015-11-15 23:21:54+00:00  666033412701032449  666033412701032448
# 2329 2015-11-15 23:05:30+00:00  666029285002620928  666029285002620928
# 2330 2015-11-15 22:32:08+00:00  666020888022790149  666020888022790144
#
# ...

# %%
api_df_c = api_df[['id','retweet_count','favorite_count']]
api_df_c
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           7549           35711
# 1     892177421306343426           5594           30873
# 2     891815181378084864           3705           23207
# 3     891689557279858688           7730           39003
# 4     891327558926688256           8332           37261
# ...                  ...            ...             ...
# 2326  666049248165822465             40              96
# 2327  666044226329800704            126             266
# 2328  666033412701032449             39             111
# 2329  666029285002620928             41             120
# 2330  666020888022790149            456            2381
#
# [2331 rows x 3 columns]

# %% [markdown]
# # Assess

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
images_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
api_df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2331 non-null   int64
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(3)
# memory usage: 54.8 KB

# %%
archive_df.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
len(archive_df.name[archive_df.name=='a'])
# Out:
# 55

# %%
len(archive_df.name[archive_df.name=='an'])
# Out:
# 7

# %%
len(archive_df.name[archive_df.name=='None'])
# Out:
# 745

# %%
archive_df[archive_df.name=='None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# ...

# %%
archive_df.name.sample(10)
# Out:
# 330     Gidget
# 1543      None
# 938        Ace
# 2342      None
# 1833      Bert
# 945       None
# 1744     Rubio
# 899       None
# 263     Winnie
# 1091      None
# Name: name, dtype: object

# %%
archive_df[archive_df.name=='Bo']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 446   819015337530290176                    NaN                  NaN
# 449   819004803107983360                    NaN                  NaN
# 553   804026241225523202                    NaN                  NaN
# 583   800188575492947969                    NaN                  NaN
# 679   789137962068021249                    NaN                  NaN
# 686   788070120937619456                    NaN                  NaN
# 876   761004547850530816                    NaN                  NaN
# 978   749996283729883136                    NaN                  NaN
# 1683  681694085539872773                    NaN                  NaN
#
#                       timestamp  \
# 446   2017-01-11 02:57:27 +0000
# 449   2017-01-11 02:15:36 +0000
# 553   2016-11-30 18:16:08 +0000
# 583   2016-11-20 04:06:37 +0000
# 679   2016-10-20 16:15:26 +0000
# 686   2016-10-17 17:32:13 +0000
# 876   2016-08-04 01:03:17 +0000
# ...

# %%
archive_df[archive_df.name=='the']['text']
# Out:
# 1527                                   Stop sending in lobsters. This is the final warning. We only rate dogs. Thank you... 9/10 https://t.co/B9ZXXKJYNx
# 1603        This is the newly formed pupper a capella group. They're just starting out but I see tons of potential. 8/10 for all https://t.co/wbAcvFoNtn
# 1797                                                    This is the happiest pupper I've ever seen. 10/10 would trade lives with https://t.co/ep8ATEJwRb
# 1815                                                          This is the saddest/sweetest/best picture I've been sent. 12/10 😢🐶 https://t.co/vQ2Lw1BLBF
# 2037    This is the best thing I've ever seen so spread it like wildfire &amp; maybe we'll find the genius who created it. 13/10 https://t.co/q6RsuOVYwU
# 2212              Never forget this vine. You will not stop watching for at least 15 minutes. This is the second coveted.. 13/10 https://t.co/roqIxCvEB3
# ...

# %%
archive_df.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
archive_df[archive_df.rating_denominator != 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %%
archive_df.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
archive_df[archive_df.rating_numerator == (121)]['text']
# Out:
# 1635    Someone help the girl is being mugged. Several are distracting her while two steal her shoes. Clever puppers 121/110 https://t.co/1zfnTJLt55
# Name: text, dtype: object

# %%
archive_df[archive_df['retweeted_status_id'].isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
archive_df[archive_df['in_reply_to_status_id'].isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
images_df
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
len(images_df.p1_dog[images_df.p1_dog==False])
# Out:
# 543

# %%
images_df[images_df.p1_dog==False]
# Out:
#                 tweet_id  \
# 6     666051853826850816
# 8     666057090499244032
# 17    666104133288665088
# 18    666268910803644416
# 21    666293911632134144
# ...                  ...
# 2026  882045870035918850
# 2046  886680336477933568
# 2052  887517139158093824
# 2071  891689557279858688
# 2074  892420643555336193
#
#                                                                                       jpg_url  \
# 6                                             https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 8                                             https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 17                                            https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18                                            https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21                                            https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# ...

# %%
images_df.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
images_df.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
api_df_c
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           7549           35711
# 1     892177421306343426           5594           30873
# 2     891815181378084864           3705           23207
# 3     891689557279858688           7730           39003
# 4     891327558926688256           8332           37261
# ...                  ...            ...             ...
# 2326  666049248165822465             40              96
# 2327  666044226329800704            126             266
# 2328  666033412701032449             39             111
# 2329  666029285002620928             41             120
# 2330  666020888022790149            456            2381
#
# [2331 rows x 3 columns]

# %%
images_df.tweet_id.duplicated().sum()
# Out:
# 0

# %%
api_df_c.sort_values(by='favorite_count')
# Out:
#                       id  retweet_count  favorite_count
# 913   753298634498793472           5623               0
# 260   840761248237133825           1727               0
# 261   840728873075638272          15719               0
# 556   801127390143516673           3975               0
# 838   763167063695355904           2977               0
# ...                  ...            ...             ...
# 1055  739238157791694849          56732          113821
# 129   866450705531457537          32395          114997
# 517   807106840509214720          55605          118892
# 397   822872901745569793          42985          131332
# 1015  744234799360020481          76282          153959
#
# [2331 rows x 3 columns]

# %%
images_df[images_df.tweet_id==744234799360020481]
# Out:
#                 tweet_id  \
# 1221  744234799360020481
#
#                                                                                       jpg_url  \
# 1221  https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg
#
#       img_num                  p1   p1_conf  p1_dog        p2   p2_conf  \
# 1221        1  Labrador_retriever  0.825333    True  ice_bear  0.044681
#
#       p2_dog       p3   p3_conf  p3_dog
# 1221   False  whippet  0.018442    True

# %% [markdown]
# # clean

# %% [markdown]
# #### Quality

# %% [markdown]
# ##### archive_df
# 1| change time stamp to datetime format.
#
# 2| change tweet id to str.
#
# 3| Remove retweets, replies and tweets with no image.
#
# 4| dog names are some times "a", "an", "the" and "None"
#
# 5| wrong numerators
#
# 6| denominator sometimes != 10
#
# 7| the type of dog (doggo puppy etc) should be categoral
#
# 8| removing unneeded columns like (in_reply_to_status_id, in_reply_to_user_id etc)
#
# 9| expanded_urls sometimes have duplicated urls
#
# 10| ratings should be float both deno and numer
#
#
# ##### images_df
# 1| change tweet id to str.
#
# 2| confidence level 2 and 3 is so low that it can be dropped (75 percent of level 2 is bellow 0.2)
#
# 3| remove retweets and replies
#
# 4| rename confidence columns to more expressive names.
#
#
# ##### api_df_c
# 1| change id to tweet_id.
#
# 2| change tweet id to str.
#
# 3| removing unneeded columns like (in_reply_to_status_id, in_reply_to_user_id etc).

# %% [markdown]
# #### Tidiness

# %% [markdown]
# ##### archive_df
# 1| doggo, floofer, pupper, puppo are variables represented as columns
#
# 2| sometimes more than one dog is there and hence 2 dog stages are there
#
# ##### images_df
# 1| merge this df with archive_df
#
# ##### api_df_c
# 1| merge this df with archive_df

# %% [markdown]
# # Clean

# %%
#creating copies to have a restore point

archive_df_clean = archive_df.copy()
images_df_clean = images_df.copy()
api_df_c_clean = api_df_c.copy()

# %%
archive_df_clean.head(1)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                             text  \
# 0  This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
#
#    retweeted_status_id  retweeted_status_user_id retweeted_status_timestamp  \
# 0                  NaN                       NaN                        NaN
#
#                                                      expanded_urls  \
# 0  https://twitter.com/dog_rates/status/892420643555336193/photo/1
#
# ...

# %%
images_df_clean.head(1)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#    img_num                      p1   p1_conf  p1_dog      p2   p2_conf  \
# 0        1  Welsh_springer_spaniel  0.465074    True  collie  0.156665
#
#    p2_dog                 p3   p3_conf  p3_dog
# 0    True  Shetland_sheepdog  0.061428    True

# %%
api_df_c_clean.head(1)
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           7549           35711

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# change time stamp to datetime format.

# %% [markdown]
# ##### Code

# %%
archive_df_clean.timestamp = pd.to_datetime(archive_df_clean.timestamp)

# %% [markdown]
# ##### Test

# %%
archive_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# change tweet id to str in archive_df_clean and image_df_clean

# %% [markdown]
# ##### Code

# %%
archive_df_clean.tweet_id = archive_df_clean.tweet_id.astype('str')
images_df_clean.tweet_id = images_df_clean.tweet_id.astype('str')
api_df_c_clean.id = api_df_c_clean.id.astype('str')

# %% [markdown]
# ##### Test

# %%
archive_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   object
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
images_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
api_df_c_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2331 non-null   object
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 54.8+ KB

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# Remove retweets, replies and tweets with no image.

# %% [markdown]
# ##### Code

# %%
archive_df_clean = archive_df_clean.loc[lambda x:x.in_reply_to_status_id.isnull()]

# %%
archive_df_clean = archive_df_clean.loc[lambda x:x.retweeted_status_id.isnull()]

# %% [markdown]
# ##### Test

# %%
archive_df_clean.in_reply_to_status_id.value_counts()
# Out:
# Series([], Name: in_reply_to_status_id, dtype: int64)

# %%
archive_df_clean.retweeted_status_id.value_counts()
# Out:
# Series([], Name: retweeted_status_id, dtype: int64)

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# dog names are some times "a", "an", "the" and "None"

# %% [markdown]
# ##### Code

# %%
archive_df_clean[archive_df_clean.name=='a']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %%
archive_df_clean.name.value_counts()
# Out:
# None        603
# a            55
# Charlie      11
# Lucy         11
# Oliver       10
#            ...
# Lillie        1
# Snicku        1
# Champ         1
# Dietrich      1
# Scott         1
# Name: name, Length: 955, dtype: int64

# %%
archive_df_clean['name'] = archive_df_clean.text.str.findall('(?:This is|named|Meet|Say hello to|name is|Here we have|Here is)\s([A-Z][^\s.,]*)')

# %%
archive_df_clean['name'] = archive_df_clean['name'].apply(lambda x: ','.join(set(x)))

# %%
archive_df_clean['name']=archive_df_clean['name'].replace('',np.nan)

# %%
archive_df_clean[archive_df_clean.name.isnull()] [['text','name']]
# Out:
#                                                                                                                                                                     text  \
# 5     Here we have a majestic great white breaching off South Africa's coast. Absolutely h*ckin breathtaking. 13/10 (IG: tucker_marlo) #BarkWeek https://t.co/kQ04fDDRmh
# 7                         When you watch your owner call another dog a good boy but then they turn back to you and say you're a great boy. 13/10 https://t.co/v0nONBcwxq
# 12                                    Here's a puppo that seems to be on the fence about something haha no but seriously someone help her. 13/10 https://t.co/BxvuXk0UCm
# 22                                  I've yet to rate a Venezuelan Hover Wiener. This is such an honor. 14/10 paw-inspiring af (IG: roxy.thedoxy) https://t.co/20VrLAA8ba
# ...

# %% [markdown]
# ##### Test

# %%
archive_df_clean.name.value_counts()
# Out:
# Lucy        11
# Charlie     11
# Cooper      10
# Oliver      10
# Tucker       9
#             ..
# Rose         1
# Mairi        1
# Newt         1
# Hercules     1
# Scott        1
# Name: name, Length: 956, dtype: int64

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# wrong numerators

# %% [markdown]
# ##### Code

# %%
archive_df_clean.rating_numerator.value_counts()
# Out:
# 12      486
# 10      436
# 11      413
# 13      287
# 9       153
# 8        98
# 7        52
# 14       38
# 5        34
# 6        32
# 3        19
# 4        16
# 2         9
# 1         5
# 26        1
# 44        1
# 165       1
# 24        1
# 60        1
# 50        1
# 144       1
# 80        1
# 84        1
# 88        1
# 121       1
# 204       1
# 420       1
# 1776      1
# 27        1
# 45        1
# 75        1
# 99        1
# 0         1
# Name: rating_numerator, dtype: int64

# %%
archive_df_clean[archive_df_clean.rating_numerator==7][['text','rating_numerator']]
# Out:
#                                                                                                                                               text  \
# 814   Another pic without a dog in it? What am I supposed to do? Rate the carpet? Fine I will. 7/10 looks adequately comfy https://t.co/OJZQ6I4gGd
# 896   Meet Toby. He has a drinking problem. Inflatable marijuana plant in the back is also not a good look. 7/10 cmon Toby https://t.co/Cim4DSj6Oi
# 998     This sherk must've leapt out of the water and into the canoe, trapping the human. Won't even help paddle smh. 7/10 https://t.co/KubWEqOIgO
# 1029                     This is Percy. He fell asleep at the wheel. Irresponsible af. 7/10 absolute menace on the roadway https://t.co/QHbvtvaw8E
# 1045      This is Harold. He looks slippery af. Probably difficult to hug. Would still try tho. 7/10 great with kids I bet https://t.co/EVuqdEO66N
# ...

# %%
archive_df_clean.loc[1662, 'rating_numerator'] = 10

# %%
archive_df_clean[archive_df_clean.rating_numerator==5][['text','rating_numerator']]
# Out:
#                                                                                                                                                   text  \
# 45            This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
# 730                         Who keeps sending in pictures without dogs in them? This needs to stop. 5/10 for the mediocre road https://t.co/ELqelxWMrC
# 956           Please stop sending it pictures that don't even have a doggo or pupper in them. Churlish af. 5/10 neat couch tho https://t.co/u2c9c7qSg8
# 1399      This is Dave. He's a tropical pup. Short lil legs (dachshund mix?) Excels underwater, but refuses to eat kibble 5/10 https://t.co/ZJnCxlIf62
# 1461                     Please only send in dogs. This t-rex is very scary. 5/10 ...might still pet (vid by @helizabethmicha) https://t.co/Vn6w5w8TO2
# ...

# %%
archive_df_clean.loc[45, 'rating_numerator'] = 13.5

# %%
archive_df_clean.loc[1508, 'rating_numerator'] = 10

# %%
archive_df_clean[archive_df_clean.rating_numerator==3][['text','rating_numerator']]
# Out:
#                                                                                                                                               text  \
# 765   This is Wesley. He's clearly trespassing. Seems rather h*ckin violent too. Weaponized forehead. 3/10 wouldn't let in https://t.co/pL7wbMRW7M
# 1189          This is Alexanderson. He's got a weird ass birth mark. Dreadful at fetch. Won't eat kibble. 3/10 wtf @Target https://t.co/FmxOpf2Sgl
# 1249     What hooligan sent in pictures w/out a dog in them? Churlish af. 3/10 just bc that's a neat fluffy bean bag chair https://t.co/wcwoGOkZvz
# 1314        This is Elliot. He's blocking the roadway. Downright rude as hell. Doesn't care that you're already late. 3/10 https://t.co/FMUxir5pYu
# 1406   This is Charl. He's a bully. Chucks that dumbbell around like its nothing. Sharp neck. Exceptionally unfluffy. 3/10 https://t.co/VfLoDZecJ7
# ...

# %%
archive_df_clean[archive_df_clean.rating_numerator==4][['text','rating_numerator']]
# Out:
#                                                                                                                                               text  \
# 883   This is Fido. He can tell the weather. Not good at fetch tho. Never comes when called. 4/10 would probably still pet https://t.co/4gOv2Q3iKP
# 912   Here's another picture without a dog in it. Idk why you guys keep sending these. 4/10 just because that's a neat rug https://t.co/mOmnL19Wsl
# 1004    Viewer discretion is advised. This is a terrible attack in progress. Not even in water (tragic af). 4/10 bad sherk https://t.co/L3U0j14N5R
# 1165                                                                              Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a
# 1219     This is Benedict. He's a feisty pup. Needs a brushing. Portable af. Looks very angry actually. 4/10 might not pet https://t.co/3oeFfHjv0Z
# ...

# %%
archive_df_clean[archive_df_clean.rating_numerator==2][['text','rating_numerator']]
# Out:
#                                                                                                                                               text  \
# 1761  Exotic pup here. Tail long af. Throat looks swollen. Might breathe fire. Exceptionally unfluffy 2/10 would still pet https://t.co/a8SqCaSo2r
# 1764  This is Crystal. She's a shitty fireman. No sense of urgency. People could be dying Crystal. 2/10 just irresponsible https://t.co/rtMtjSl9pz
# 1920    This is Henry. He's a shit dog. Short pointy ears. Leaves trail of pee. Not fluffy. Doesn't come when called. 2/10 https://t.co/Pu9RhfHDEQ
# 2079   Scary dog here. Too many legs. Extra tail. Not soft, let alone fluffy. Won't bark. Moves sideways. Has weapon. 2/10 https://t.co/XOPXCSXiUT
# 2237  This lil pup is Oliver. Hops around. Has wings but doesn't fly (lame). Annoying chirp. Won't catch tennis balls 2/10 https://t.co/DnhUw0aBM2
# ...

# %%
archive_df_clean[archive_df_clean.rating_numerator==1][['text','rating_numerator']]
# Out:
#                                                                                                                                               text  \
# 1869                     What kind of person sends in a picture without a dog in it? 1/10 just because that's a nice table https://t.co/RDXCfk8hK0
# 2091      Flamboyant pup here. Probably poisonous. Won't eat kibble. Doesn't bark. Slow af. Petting doesn't look fun. 1/10 https://t.co/jxukeh2BeO
# 2261  Never seen dog like this. Breathes heavy. Tilts head in a pattern. No bark. Shitty at fetch. Not even cordless. 1/10 https://t.co/i9iSGNn3fx
# 2335      This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv
# 2338        Not familiar with this breed. No tail (weird). Only 2 legs. Doesn't bark. Surprisingly quick. Shits eggs. 1/10 https://t.co/Asgdc6kuLX
#
#       rating_numerator
# 1869               1.0
# 2091               1.0
# 2261               1.0
# ...

# %%
valuesc = [26 ,44, 165, 24, 60, 50, 144, 80, 84, 88, 121, 204, 420, 1776, 27, 45, 75, 99, 0]
type(valuesc)
# Out:
# list

# %%
archive_df_clean.loc[2335, 'rating_numerator'] = 9

# %%
archive_df_clean[archive_df_clean.rating_numerator.isin(valuesc)][['text','rating_numerator']]
# Out:
#                                                                                                                                                                            text  \
# 315                                                           When you're so blinded by your systematic plagiarism that you forget what day it is. 0/10 https://t.co/YbEJPkg4Ag
# 433                                                                         The floofs have been released I repeat the floofs have been released. 84/70 https://t.co/NIYC820tmd
# 516   Meet Sam. She smiles 24/7 &amp; secretly aspires to be a reindeer. \nKeep Sam smiling by clicking and sharing this link:\nhttps://t.co/98tB8y7y7t https://t.co/LouL5vdvxx
# 695                                            This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wuqaPS
# ...

# %%
archive_df_clean.drop(516, inplace=True)

# %%
archive_df_clean.loc[[695,763,1712], 'rating_numerator'] = [9.75, 11.27,11.26]

# %%
rating = archive_df_clean.text.str.extract('((?:\d+\.)?\d+)\/(\d+)', expand=True)
rating.columns = ['rating_numerator', 'rating_denominator']
rating.rating_numerator.value_counts()
# Out:
# 12       486
# 10       436
# 11       413
# 13       287
# 9        153
# 8         98
# 7         52
# 14        38
# 5         33
# 6         32
# 3         19
# 4         16
# 2          9
# 1          5
# 420        1
# 60         1
# 144        1
# 165        1
# 45         1
# 0          1
# 44         1
# 1776       1
# 99         1
# 121        1
# 204        1
# 13.5       1
# 9.75       1
# 11.26      1
# 84         1
# 88         1
# 11.27      1
# 80         1
# 50         1
# Name: rating_numerator, dtype: int64

# %%
archive_df_clean['rating_numerator'].value_counts()
# Out:
# 12.00      486
# 10.00      438
# 11.00      413
# 13.00      287
# 9.00       154
# 8.00        98
# 7.00        51
# 14.00       38
# 6.00        32
# 5.00        32
# 3.00        19
# 4.00        16
# 2.00         9
# 1.00         4
# 13.50        1
# 84.00        1
# 0.00         1
# 420.00       1
# 50.00        1
# 1776.00      1
# 60.00        1
# 44.00        1
# 144.00       1
# 88.00        1
# 11.26        1
# 11.27        1
# 121.00       1
# 9.75         1
# 99.00        1
# 204.00       1
# 45.00        1
# 165.00       1
# 80.00        1
# Name: rating_numerator, dtype: int64

# %%
archive_df_clean.rating_numerator=rating.rating_numerator
archive_df_clean.rating_denominator=rating.rating_denominator

# %%
archive_df_clean.rating_numerator=archive_df_clean.rating_numerator.astype('float')
archive_df_clean.rating_denominator=archive_df_clean.rating_denominator.astype('float')

# %%
archive_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2096 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2096 non-null   object
#  1   in_reply_to_status_id       0 non-null      float64
#  2   in_reply_to_user_id         0 non-null      float64
#  3   timestamp                   2096 non-null   datetime64[ns, UTC]
#  4   source                      2096 non-null   object
#  5   text                        2096 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2093 non-null   object
#  10  rating_numerator            2096 non-null   float64
#  11  rating_denominator          2096 non-null   float64
#  12  name                        1421 non-null   object
# ...

# %% [markdown]
# ##### Test

# %%
archive_df_clean.rating_numerator.value_counts()
# Out:
# 12.00      486
# 10.00      436
# 11.00      413
# 13.00      287
# 9.00       153
# 8.00        98
# 7.00        52
# 14.00       38
# 5.00        33
# 6.00        32
# 3.00        19
# 4.00        16
# 2.00         9
# 1.00         5
# 13.50        1
# 84.00        1
# 0.00         1
# 420.00       1
# 50.00        1
# 1776.00      1
# 60.00        1
# 44.00        1
# 144.00       1
# 88.00        1
# 11.26        1
# 11.27        1
# 121.00       1
# 9.75         1
# 99.00        1
# 204.00       1
# 45.00        1
# 165.00       1
# 80.00        1
# Name: rating_numerator, dtype: int64

# %%
archive_df_clean.rating_denominator.value_counts()
# Out:
# 10.0     2080
# 50.0        3
# 80.0        2
# 11.0        2
# 150.0       1
# 110.0       1
# 90.0        1
# 70.0        1
# 170.0       1
# 2.0         1
# 120.0       1
# 40.0        1
# 20.0        1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# denominator sometimes != 10

# %% [markdown]
# ##### Code

# %%
archive_df_clean[archive_df_clean.rating_denominator != 10][['text','rating_denominator']]
# Out:
#                                                                                                                                                     text  \
# 433                                                  The floofs have been released I repeat the floofs have been released. 84/70 https://t.co/NIYC820tmd
# 902                                                                       Why does this never happen at my front door... 165/150 https://t.co/HmwrdfEfUE
# 1068        After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https://t.co/XAVDNDaVgQ
# 1120                           Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once https://t.co/yGQI3He3xv
# 1165                                                                                    Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a
# ...

# %%
archive_df_clean.loc[[1068,  1165, 1662, 2335], 'rating_denominator'] = [10,10,10,10]

# %% [markdown]
# ##### Test

# %%
archive_df_clean[archive_df_clean.rating_denominator != 10][['text','rating_denominator']]
# Out:
#                                                                                                                                                     text  \
# 433                                                  The floofs have been released I repeat the floofs have been released. 84/70 https://t.co/NIYC820tmd
# 902                                                                       Why does this never happen at my front door... 165/150 https://t.co/HmwrdfEfUE
# 1120                           Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once https://t.co/yGQI3He3xv
# 1202                               This is Bluebert. He just saw that both #FinalFur match ups are split 50/50. Amazed af. 11/10 https://t.co/Kky1DPG4iq
# 1228                                                       Happy Saturday here's 9 puppers on a bench. 99/90 good work everybody https://t.co/mpvaVxKmc1
# ...

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# removing unneeded columns like (in_reply_to_status_id, in_reply_to_user_id etc)

# %% [markdown]
# ##### Code

# %%
archive_df_clean.keys()
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
archive_df_clean.drop(columns=['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'], inplace=True)

# %%
archive_df_clean.drop(columns=['source'], inplace=True)

# %% [markdown]
# ##### Test

# %%
archive_df_clean
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2351  666049248165822465 2015-11-16 00:24:50+00:00
# 2352  666044226329800704 2015-11-16 00:04:52+00:00
# 2353  666033412701032449 2015-11-15 23:21:54+00:00
# 2354  666029285002620928 2015-11-15 23:05:30+00:00
# 2355  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                                                                                                                                     text  \
# 0                                                          This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# ...

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# expanded_urls sometimes have duplicated urls

# %% [markdown]
# ##### Code

# %%
archive_df_clean.expanded_urls.fillna('', inplace=True)

# %%
for expanded in archive_df_clean.expanded_urls:
    if ',' in expanded:
        x = expanded.split(',')[1]
        archive_df_clean.expanded_urls.replace(expanded,x,inplace=True)

# %% [markdown]
# ##### Test

# %%
archive_df_clean.loc[4,'expanded_urls']
# Out:
# 'https://twitter.com/dog_rates/status/891327558926688256/photo/1'

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# remove retweets and replies and no images from archive_df_clean and images_df_clean

# %% [markdown]
# ##### Code

# %%
list_archive_id = list(archive_df_clean.tweet_id)
len(list_archive_id)
# Out:
# 2096

# %%
list_images_id = list(images_df_clean.tweet_id)
len(list_images_id)
# Out:
# 2075

# %%
total = set(list_archive_id).intersection(list_images_id)
len(total)
# Out:
# 1970

# %%
archive_df_clean = archive_df_clean[archive_df_clean['tweet_id'].isin(total)]

# %%
images_df_clean = images_df_clean[images_df_clean['tweet_id'].isin(total)]

# %%
api_df_c_clean = api_df_c_clean[api_df_c_clean['id'].isin(total)]

# %%
last = list(api_df_c_clean.id)
last
# Out:
# ['892420643555336193',
#  '892177421306343426',
#  '891815181378084864',
#  '891689557279858688',
#  '891327558926688256',
#  '891087950875897856',
#  '890971913173991426',
#  '890729181411237888',
#  '890609185150312448',
#  '890240255349198849',
#  '890006608113172480',
#  '889880896479866881',
#  '889665388333682689',
#  '889638837579907072',
#  '889531135344209921',
#  '889278841981685760',
#  '888917238123831296',
#  '888804989199671297',
#  '888554962724278272',
#  '888078434458587136',
#  '887705289381826560',
#  '887517139158093824',
#  '887473957103951883',
#  '887343217045368832',
#  '887101392804085760',
#  '886983233522544640',
#  '886736880519319552',
#  '886680336477933568',
#  '886366144734445568',
#  '886258384151887873',
#  '885984800019947520',
#  '885528943205470208',
#  '885167619883638784',
#  '884925521741709313',
#  '884876753390489601',
#  '884562892145688576',
#  '884441805382717440',
#  '884162670584377345',
#  '883838122936631299',
#  '883482846933004288',
# ...

# %%
archive_df_clean = archive_df_clean[archive_df_clean['tweet_id'].isin(last)]

# %%
images_df_clean = images_df_clean[images_df_clean['tweet_id'].isin(last)]

# %% [markdown]
# ##### Test

# %%
archive_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1963 entries, 0 to 2355
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1963 non-null   object
#  1   timestamp           1963 non-null   datetime64[ns, UTC]
#  2   text                1963 non-null   object
#  3   expanded_urls       1963 non-null   object
#  4   rating_numerator    1963 non-null   float64
#  5   rating_denominator  1963 non-null   float64
#  6   name                1372 non-null   object
#  7   doggo               1963 non-null   object
#  8   floofer             1963 non-null   object
#  9   pupper              1963 non-null   object
#  10  puppo               1963 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), object(8)
# memory usage: 184.0+ KB

# %%
images_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1963 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  1963 non-null   object
#  1   jpg_url   1963 non-null   object
#  2   img_num   1963 non-null   int64
#  3   p1        1963 non-null   object
#  4   p1_conf   1963 non-null   float64
#  5   p1_dog    1963 non-null   bool
#  6   p2        1963 non-null   object
#  7   p2_conf   1963 non-null   float64
#  8   p2_dog    1963 non-null   bool
#  9   p3        1963 non-null   object
#  10  p3_conf   1963 non-null   float64
#  11  p3_dog    1963 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 159.1+ KB

# %%
api_df_c_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1963 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1963 non-null   object
#  1   retweet_count   1963 non-null   int64
#  2   favorite_count  1963 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.3+ KB

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# confidence level 2 and 3 is so low that it can be dropped (75 percent of level 2 is bellow 0.2)

# %% [markdown]
# ##### Code

# %%
images_df_clean
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
images_df_clean.drop(columns=['p2','p2_conf','p2_dog','p3','p3_conf','p3_dog'], inplace=True)

# %%
images_df_clean.rename(columns={'p1':'prediction','p1_conf':'prediction_confidence','p1_dog':'dog'},inplace=True)

# %% [markdown]
# ##### Test

# %%
images_df_clean
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num              prediction  prediction_confidence    dog
# ...

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# change id to tweet_id.

# %% [markdown]
# ##### Code

# %%
api_df_c_clean=api_df_c_clean.rename(columns = {'id':'tweet_id'})

# %% [markdown]
# ##### Test

# %%
api_df_c_clean
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           7549           35711
# 1     892177421306343426           5594           30873
# 2     891815181378084864           3705           23207
# 3     891689557279858688           7730           39003
# 4     891327558926688256           8332           37261
# ...                  ...            ...             ...
# 2326  666049248165822465             40              96
# 2327  666044226329800704            126             266
# 2328  666033412701032449             39             111
# 2329  666029285002620928             41             120
# 2330  666020888022790149            456            2381
#
# [1963 rows x 3 columns]

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# doggo, floofer, pupper, puppo are variables represented as columns

# %% [markdown]
# ##### Code

# %%
'''archive_df_clean['type']= 5
archive_df_clean'''
# Out:
# "archive_df_clean['type']= 5\narchive_df_clean"

# %%
# handle none
archive_df_clean.doggo.replace('None', '', inplace=True)
archive_df_clean.floofer.replace('None', '', inplace=True)
archive_df_clean.pupper.replace('None', '', inplace=True)
archive_df_clean.puppo.replace('None', '', inplace=True)

# merge into column
archive_df_clean['type'] = archive_df_clean.doggo + archive_df_clean.floofer + archive_df_clean.pupper + archive_df_clean.puppo

# handle multiple stages
archive_df_clean.loc[archive_df_clean.type == 'doggopupper', 'type'] = 'doggo, pupper'
archive_df_clean.loc[archive_df_clean.type == 'doggopuppo', 'type'] = 'doggo, puppo'
archive_df_clean.loc[archive_df_clean.type == 'doggofloofer', 'type'] = 'doggo, floofer'

# handle missing values
archive_df_clean.loc[archive_df_clean.type == '', 'type'] = np.nan

# %%
# this was the old code which didn't show multiples 

"""for index, row in archive_df_clean.iterrows():
    if row.doggo == 'doggo':
        archive_df_clean.loc[index, 'type'] = 'doggo'
        
    elif row.floofer == 'floofer':
        archive_df_clean.loc[index, 'type'] = 'floofer'
        
    elif row.pupper == 'pupper':
        archive_df_clean.loc[index, 'type'] = 'pupper'
        
    elif row.puppo == 'puppo':
        archive_df_clean.loc[index, 'type'] = 'puppo'"""
# Out:
# "for index, row in archive_df_clean.iterrows():\n    if row.doggo == 'doggo':\n        archive_df_clean.loc[index, 'type'] = 'doggo'\n        \n    elif row.floofer == 'floofer':\n        archive_df_clean.loc[index, 'type'] = 'floofer'\n        \n    elif row.pupper == 'pupper':\n        archive_df_clean.loc[index, 'type'] = 'pupper'\n        \n    elif row.puppo == 'puppo':\n        archive_df_clean.loc[index, 'type'] = 'puppo'"

# %%
archive_df_clean.drop(columns=['doggo','floofer','pupper','puppo'],inplace=True)

# %%
#archive_df_clean['type'].replace(5,np.nan,inplace=True)

# %% [markdown]
# ##### Test

# %%
archive_df_clean['type'].value_counts(dropna= False)
# Out:
# NaN               1661
# pupper             201
# doggo               62
# puppo               22
# doggo, pupper        8
# floofer              7
# doggo, puppo         1
# doggo, floofer       1
# Name: type, dtype: int64

# %%
archive_df_clean
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2351  666049248165822465 2015-11-16 00:24:50+00:00
# 2352  666044226329800704 2015-11-16 00:04:52+00:00
# 2353  666033412701032449 2015-11-15 23:21:54+00:00
# 2354  666029285002620928 2015-11-15 23:05:30+00:00
# 2355  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                                                                                                                                     text  \
# 0                                                          This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# ...

# %% [markdown]
# # _______________

# %% [markdown]
# ##### Define

# %% [markdown]
# merge this df with archive_df

# %% [markdown]
# ##### Code

# %%
archive_df_clean = pd.merge(archive_df_clean, api_df_c_clean,
                            on=['tweet_id'], how='left')

# %% [markdown]
# ##### Test

# %%
archive_df_clean
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 1958  666049248165822465 2015-11-16 00:24:50+00:00
# 1959  666044226329800704 2015-11-16 00:04:52+00:00
# 1960  666033412701032449 2015-11-15 23:21:54+00:00
# 1961  666029285002620928 2015-11-15 23:05:30+00:00
# 1962  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                                                                                                                                     text  \
# 0                                                          This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# ...

# %%
master_df = pd.merge(archive_df_clean, images_df_clean,
                            on=['tweet_id'], how='left')

# %%
master_df
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 1958  666049248165822465 2015-11-16 00:24:50+00:00
# 1959  666044226329800704 2015-11-16 00:04:52+00:00
# 1960  666033412701032449 2015-11-15 23:21:54+00:00
# 1961  666029285002620928 2015-11-15 23:05:30+00:00
# 1962  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                                                                                                                                     text  \
# 0                                                          This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# ...

# %%
master_df.to_csv('twitter_archive_master.csv', index=False)

# %%
archive_df_clean.to_csv('archive_clean.csv', index=False)

# %%
images_df_clean.to_csv('images_clean.csv', index=False)

# %% [markdown]
# # Insights and Visualization

# %%
xyz = master_df.name.dropna()
wc = WordCloud(background_color="white", max_words=2000)
master_df.name.value_counts().head()
# Out:
# Oliver     10
# Cooper     10
# Charlie    10
# Tucker      9
# Lucy        9
# Name: name, dtype: int64

# %%
wc.generate(' '.join(xyz));

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Depending on the data on hand: The top three apundent names are Charlie    Oliver     Cooper

# %% [markdown]
# # _______________

# %%
rating_fav_re = master_df[['rating_numerator','favorite_count','retweet_count']][master_df.rating_numerator<25].sort_values(by='rating_numerator',ascending=False)
rating_fav_re
# Out:
#       rating_numerator  favorite_count  retweet_count
# 144               14.0           26580           5940
# 250               14.0           27399           6421
# 539               14.0           13633           4314
# 129               14.0           15818           5446
# 271               14.0           12529           2197
# ...                ...             ...            ...
# 1942               1.0             133             58
# 1493               1.0            5981           2449
# 1705               1.0             785            357
# 1945               1.0           13439           5886
# 229                0.0           22177           2955
#
# [1949 rows x 3 columns]

# %%
sns.lmplot(x='rating_numerator', y='favorite_count',data = rating_fav_re)
plt.show()

# %%
sns.lmplot(x='rating_numerator', y='retweet_count',data = rating_fav_re)
plt.show()

# %% [markdown]
# As it can be deducted clearly that the higher the rating the dog gets, the higher the retweets and favorites.
# I have removed all ratings above 25 since these were made with a different scale and just made for laughs.

# %% [markdown]
# # _______________

# %%
plt.scatter(master_df['favorite_count'], master_df['retweet_count']);
plt.xlabel('Favorites');
plt.ylabel('Retweets');
plt.title('Retweets and favorites Scatter plot');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-8b6d9d36601a> in <module>
# ----> 1 plt.scatter(master_df['favorite_count'], master_df['retweet_count'],figsize=(12,3));
#       2 plt.xlabel('Favorites');
#       3 plt.ylabel('Retweets');
#       4 plt.title('Retweets and favorites Scatter plot');
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %% [markdown]
# Here is a no brainer, the higher a tweet gets retweeted the higher it gets favourited.

# %% [markdown]
# # _______________

# %%
fav_counts_prediction = master_df[master_df.prediction != 'none'].groupby(['prediction'])['favorite_count'].sum().sort_values(ascending = False)

fav_counts_prediction=fav_counts_prediction.head(5)

fav_counts_prediction
# Out:
# prediction
# golden_retriever      1550268
# Labrador_retriever     972719
# Pembroke               917297
# Chihuahua              632276
# Samoyed                473383
# Name: favorite_count, dtype: int64

# %%
retweet_counts_prediction = master_df[master_df.prediction != 'none'].groupby(['prediction'])['retweet_count'].sum().sort_values(ascending = False)

retweet_counts_prediction=retweet_counts_prediction.head(5)

retweet_counts_prediction
# Out:
# prediction
# golden_retriever      436497
# Labrador_retriever    305920
# Pembroke              244009
# Chihuahua             195917
# Samoyed               151601
# Name: retweet_count, dtype: int64

# %%
plt.figure(figsize=(12,3))
plt.barh(fav_counts_prediction.index, fav_counts_prediction)

plt.xlabel('Favorites')

plt.title('Most loved Dogs')

ax = plt.gca()

ax.get_xaxis().get_major_formatter().set_scientific(False)


plt.draw();

# %%
plt.barh(retweet_counts_prediction.index, retweet_counts_prediction)

plt.xlabel('Retweets')

plt.title('Most loved Dogs')

ax = plt.gca()

ax.get_xaxis().get_major_formatter().set_scientific(False)

plt.draw();

# %% [markdown]
# The most loved dog when it comes to retweets and favorites is:
# golden_retriever
